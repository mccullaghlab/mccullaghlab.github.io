# %% [markdown]
# # Week 6 Hands-On: WebMO (Gaussian on TIGER)
# **Course:** Computational Chemistry
# **Activity type:** Hands-on tutorial + short assignment

# %% [markdown]
# ---
# ## TIGER / WebMO Access Information
#
# You will be using **WebMO with Gaussian** running on the **TIGER HPC system**.
#
# ### Access Setup
# - Your TIGER access has been created.
# - You have been added to TIGER's **Gaussian access group**.
#
# ### WebMO URLs
# - **WebMO Pro version:**
#   [https://tiger.hpc.okstate.edu/~webmopro](https://tiger.hpc.okstate.edu/~webmopro)
#
# - **WebMO Basic version:**
#   [https://tiger.hpc.okstate.edu/~webmo](https://tiger.hpc.okstate.edu/~webmo)
#
# For this course, use **WebMO Pro** unless instructed otherwise.
#
# ### Login Instructions
# - Use your **short O-Key username** (e.g., `martmcc`).
# - Use your O-Key password.
#
# If you cannot log in:
# 1. Confirm you are using your short O-Key username (not your full email).
# 2. Confirm VPN access if off campus.
# 3. Contact the instructor if access problems persist.

# %% [markdown]
# ---
# ## Learning Goals
# By the end of this activity you should be able to:
# 1. Log into WebMO and navigate the interface.
# 2. Build a molecule using the WebMO Builder.
# 3. Run a Gaussian geometry optimization.
# 4. Run a Gaussian frequency calculation and interpret the results.
# 5. Identify whether a structure is a minimum (no imaginary frequencies).

# %% [markdown]
# ---
# ## 1. Build a Molecule (Example: Ethanol)
# 1. Selet `Create New Job` from the `New Job` menu
#    ![new_job](img/job_manager_create_new_job_highlighted.png)
# 3. Construct ethanol (CH$_3$CH$_2$OH) using tools to add and bond carbons and oxygen.
#    ![create_ethanol](img/create_ethanol.png)
# 5. Add hydrogens automatically using the `Add Hydrogens` option from `Cleanup` menu
#    ![add_hydrogens](img/build_molecule_add_hydrogens.png)
# 6. Perform an initial geometry optimization (to refine your handmade positioning) using the `Mechanics Optimize` from the `Cleanup` menu.
#
# Set:
# - Charge = 0
# - Multiplicity = 1

# %% [markdown]
# ---
# ## 2. Geometry Optimization (Gaussian)
# 1. Press the right arrow on the bottom right of the molecular building screen to progress to the job options.
# 2. Select **Gaussian03** as the engine in the next screen.
#    ![Gaussian03](img/choose_computational_engine.png)
# 4. Press the right arrow on the bottom right to advance Configure Job Options.  Choose Job Type: Geometry Optimization.
#     ![config](img/configure_geom_opt.png)
# 6. Method:  HF (can try others later)
# 7. Basis Set: 6-31G(d).
# 8. Name your job clearly (e.g., ethanol_opt_HF).
# 9. Submit and monitor in Job Manager by hitting the right arrow on the bottom right of your screen.
#     ![monitor](img/monitor_jobs.png)
#
# When the job Status reads `Complete`, hit the little magnifying glass to look at the output information.
# ![output](img/geom_opt_output.png)
# Record:
# - Final electronic energy (Hartree).
# - C-C and C-O bond lengths (by highlighting the atoms in the image)

# %% [markdown]
# ---
# ## 3. Frequency Calculation
# 1. Start a new job from the optimized geometry by clicking the `New Job Using This Geometry` button at the bottom of the optimized geometry when viewing the output.
# 2. In the new window, click the right arrow on the bottom right to choose the Computational Engine.
# 3. Select `Gaussian03` again and click the right arrow on the bottom right to configure your job.
# 4. In this screen select `Vibrational Frequencies` from the `Calculation` menu.
#    ![config_vib](img/configure_frequency_calculation.png)
# 6. Use the same method and basis set as the geometry optimation (why?).
# 7. Submit the job.
#
# Record:
# - Number of imaginary frequencies.
# - Lowest three vibrational frequencies.
# - Does this structure correspond to a minimum? Why?

# %% [markdown]
# ---
# # Assignment (Submit on Canvas)
#
# Perform a geometry optimization and frequency caculation for acetone.
#
# ## Deliverables
# ### A. Setup (2 pts)
# - Molecule name + screenshot
# - Charge and multiplicity
#
# ### B. Optimization (4 pts)
# - Method and basis set
# - Final energy
# - Two geometric parameters
#
# ### C. Frequency (3 pts)
# - Number of imaginary frequencies
# - Lowest three frequencies
# - Statement about minimum
#
# ### D. Reflection (1 pt)
# 2–3 sentences: What was most confusing about WebMO?
